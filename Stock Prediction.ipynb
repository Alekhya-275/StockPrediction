# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Stock.csv')

# %%
 df.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
print(df.shape)
# Out:
# (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df[['Date','Open','Close']]
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))
df.set_index('Date',drop=True,inplace=True)
df.head(5)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='black')
ax[0].set_xlabel('Year',size=20)
ax[0].set_ylabel('Price',size=20)
ax[0].legend()
ax[1].plot(df['Close'],label='Close',color='blue')
ax[1].set_xlabel('Year',size=20)
ax[1].set_ylabel('Price',size=20)
ax[1].legend()
fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
training_size = round(len(df) * 0.75)
training_size
# Out:
# 757

# %%
train_data = df[:training_size]
test_data = df[training_size:]
train_data.shape, test_data.shape
# Out:
# ((757, 2), (252, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)):
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((707, 50, 2), (707, 2), (202, 50, 2), (202, 2))

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))
model.add(Dropout(0.1))
model.add(LSTM(units=50))
model.add(Dense(2))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq,test_label), verbose=1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 61ms/step - loss: 5.0793e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0014 - val_mean_absolute_error: 0.0243
# Epoch 2/100
# 23/23 [==============================] - 1s 52ms/step - loss: 4.9183e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0015 - val_mean_absolute_error: 0.0249
# Epoch 3/100
# 23/23 [==============================] - 1s 55ms/step - loss: 4.9163e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0013 - val_mean_absolute_error: 0.0228
# Epoch 4/100
# 23/23 [==============================] - 1s 51ms/step - loss: 5.4277e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0013 - val_mean_absolute_error: 0.0223
# Epoch 5/100
# 23/23 [==============================] - 1s 46ms/step - loss: 4.7857e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0012 - val_mean_absolute_error: 0.0212
# Epoch 6/100
# 23/23 [==============================] - 2s 88ms/step - loss: 5.0708e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0014 - val_mean_absolute_error: 0.0245
# Epoch 7/100
# 23/23 [==============================] - 3s 123ms/step - loss: 5.1860e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0013 - val_mean_absolute_error: 0.0233
# Epoch 8/100
# 23/23 [==============================] - 3s 137ms/step - loss: 5.4693e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0019 - val_mean_absolute_error: 0.0281
# Epoch 9/100
# 23/23 [==============================] - 2s 104ms/step - loss: 5.4164e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0013 - val_mean_absolute_error: 0.0228
# Epoch 10/100
# 23/23 [==============================] - 2s 88ms/step - loss: 4.8871e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269
# Epoch 11/100
# 23/23 [==============================] - 2s 90ms/step - loss: 5.3560e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 12/100
# 23/23 [==============================] - 2s 102ms/step - loss: 4.6112e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0017 - val_mean_absolute_error: 0.0279
# Epoch 13/100
# 23/23 [==============================] - 3s 123ms/step - loss: 4.5300e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0013 - val_mean_absolute_error: 0.0240
# Epoch 14/100
# 23/23 [==============================] - 3s 127ms/step - loss: 5.3954e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 15/100
# 23/23 [==============================] - 1s 53ms/step - loss: 5.6145e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0016 - val_mean_absolute_error: 0.0282
# Epoch 16/100
# 23/23 [==============================] - 1s 46ms/step - loss: 5.3113e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0013 - val_mean_absolute_error: 0.0236
# Epoch 17/100
# 23/23 [==============================] - 1s 50ms/step - loss: 5.1777e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0014 - val_mean_absolute_error: 0.0256
# Epoch 18/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.5690e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0015 - val_mean_absolute_error: 0.0275
# Epoch 19/100
# 23/23 [==============================] - 1s 48ms/step - loss: 6.4030e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0018 - val_mean_absolute_error: 0.0285
# Epoch 20/100
# 23/23 [==============================] - 1s 52ms/step - loss: 4.9262e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0016 - val_mean_absolute_error: 0.0275
# Epoch 21/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.8676e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0016 - val_mean_absolute_error: 0.0258
# Epoch 22/100
# 23/23 [==============================] - 1s 50ms/step - loss: 5.2591e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0018 - val_mean_absolute_error: 0.0306
# Epoch 23/100
# 23/23 [==============================] - 1s 48ms/step - loss: 5.0532e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0024 - val_mean_absolute_error: 0.0361
# Epoch 24/100
# 23/23 [==============================] - 2s 78ms/step - loss: 5.6401e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0022 - val_mean_absolute_error: 0.0312
# Epoch 25/100
# 23/23 [==============================] - 2s 76ms/step - loss: 4.3442e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0023 - val_mean_absolute_error: 0.0326
# Epoch 26/100
# 23/23 [==============================] - 1s 61ms/step - loss: 4.4996e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0021 - val_mean_absolute_error: 0.0307
# Epoch 27/100
# 23/23 [==============================] - 1s 47ms/step - loss: 4.7730e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0020 - val_mean_absolute_error: 0.0299
# Epoch 28/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.3174e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0018 - val_mean_absolute_error: 0.0282
# Epoch 29/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.7939e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0021 - val_mean_absolute_error: 0.0300
# Epoch 30/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.4905e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0016 - val_mean_absolute_error: 0.0252
# Epoch 31/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.3281e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0018 - val_mean_absolute_error: 0.0291
# Epoch 32/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.2698e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0027 - val_mean_absolute_error: 0.0365
# Epoch 33/100
# 23/23 [==============================] - 1s 48ms/step - loss: 5.2125e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0026 - val_mean_absolute_error: 0.0366
# Epoch 34/100
# 23/23 [==============================] - 1s 49ms/step - loss: 4.6779e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0021 - val_mean_absolute_error: 0.0305
# Epoch 35/100
# 23/23 [==============================] - 2s 68ms/step - loss: 4.2373e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0018 - val_mean_absolute_error: 0.0284
# Epoch 36/100
# 23/23 [==============================] - 2s 79ms/step - loss: 4.9048e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0026 - val_mean_absolute_error: 0.0347
# Epoch 37/100
# 23/23 [==============================] - 2s 74ms/step - loss: 5.3323e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0025 - val_mean_absolute_error: 0.0342
# Epoch 38/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.5708e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0016 - val_mean_absolute_error: 0.0258
# Epoch 39/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.1188e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0020 - val_mean_absolute_error: 0.0309
# Epoch 40/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.4689e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 41/100
# 23/23 [==============================] - 1s 47ms/step - loss: 5.0692e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0020 - val_mean_absolute_error: 0.0300
# Epoch 42/100
# 23/23 [==============================] - 1s 50ms/step - loss: 5.2057e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0019 - val_mean_absolute_error: 0.0290
# Epoch 43/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.3470e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0026 - val_mean_absolute_error: 0.0361
# Epoch 44/100
# 23/23 [==============================] - 1s 52ms/step - loss: 4.5100e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0028 - val_mean_absolute_error: 0.0401
# Epoch 45/100
# 23/23 [==============================] - 1s 51ms/step - loss: 5.1099e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0017 - val_mean_absolute_error: 0.0272
# Epoch 46/100
# 23/23 [==============================] - 1s 60ms/step - loss: 4.7114e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0022 - val_mean_absolute_error: 0.0315
# Epoch 47/100
# 23/23 [==============================] - 2s 78ms/step - loss: 4.5216e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0025 - val_mean_absolute_error: 0.0341
# Epoch 48/100
# 23/23 [==============================] - 2s 82ms/step - loss: 4.1821e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0019 - val_mean_absolute_error: 0.0283
# Epoch 49/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.4219e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0018 - val_mean_absolute_error: 0.0283
# Epoch 50/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.9105e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0016 - val_mean_absolute_error: 0.0268
# Epoch 51/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.9631e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0024 - val_mean_absolute_error: 0.0328
# Epoch 52/100
# 23/23 [==============================] - 1s 47ms/step - loss: 4.3768e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0021 - val_mean_absolute_error: 0.0305
# Epoch 53/100
# 23/23 [==============================] - 1s 49ms/step - loss: 4.2170e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0018 - val_mean_absolute_error: 0.0282
# Epoch 54/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.5502e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0019 - val_mean_absolute_error: 0.0296
# Epoch 55/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.5100e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0027 - val_mean_absolute_error: 0.0354
# Epoch 56/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.1979e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0025 - val_mean_absolute_error: 0.0334
# Epoch 57/100
# 23/23 [==============================] - 1s 59ms/step - loss: 4.3308e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0016 - val_mean_absolute_error: 0.0261
# Epoch 58/100
# 23/23 [==============================] - 2s 83ms/step - loss: 4.5480e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0035 - val_mean_absolute_error: 0.0445
# Epoch 59/100
# 23/23 [==============================] - 2s 79ms/step - loss: 5.6167e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0025 - val_mean_absolute_error: 0.0361
# Epoch 60/100
# 23/23 [==============================] - 1s 47ms/step - loss: 4.3580e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 61/100
# 23/23 [==============================] - 1s 48ms/step - loss: 5.5703e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0032 - val_mean_absolute_error: 0.0418
# Epoch 62/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.7331e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0017 - val_mean_absolute_error: 0.0289
# Epoch 63/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.7524e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0025 - val_mean_absolute_error: 0.0340
# Epoch 64/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.4620e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0028 - val_mean_absolute_error: 0.0377
# Epoch 65/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.3852e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0022 - val_mean_absolute_error: 0.0319
# Epoch 66/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.1197e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0021 - val_mean_absolute_error: 0.0306
# Epoch 67/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.3777e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0023 - val_mean_absolute_error: 0.0320
# Epoch 68/100
# 23/23 [==============================] - 1s 54ms/step - loss: 5.2260e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0022 - val_mean_absolute_error: 0.0321
# Epoch 69/100
# 23/23 [==============================] - 2s 79ms/step - loss: 4.7317e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0019 - val_mean_absolute_error: 0.0298
# Epoch 70/100
# 23/23 [==============================] - 2s 78ms/step - loss: 4.1704e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0028 - val_mean_absolute_error: 0.0363
# Epoch 71/100
# 23/23 [==============================] - 1s 56ms/step - loss: 3.8649e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0019 - val_mean_absolute_error: 0.0287
# Epoch 72/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.0815e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0027 - val_mean_absolute_error: 0.0356
# Epoch 73/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.2784e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0022 - val_mean_absolute_error: 0.0320
# Epoch 74/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.0548e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0018 - val_mean_absolute_error: 0.0272
# Epoch 75/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.0716e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0029 - val_mean_absolute_error: 0.0398
# Epoch 76/100
# 23/23 [==============================] - 1s 47ms/step - loss: 3.9933e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0036 - val_mean_absolute_error: 0.0454
# Epoch 77/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.4083e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0025 - val_mean_absolute_error: 0.0344
# Epoch 78/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.2335e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0021 - val_mean_absolute_error: 0.0303
# Epoch 79/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.1281e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0019 - val_mean_absolute_error: 0.0285
# Epoch 80/100
# 23/23 [==============================] - 2s 79ms/step - loss: 4.7462e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0021 - val_mean_absolute_error: 0.0330
# Epoch 81/100
# 23/23 [==============================] - 2s 81ms/step - loss: 4.6270e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0022 - val_mean_absolute_error: 0.0313
# Epoch 82/100
# 23/23 [==============================] - 1s 64ms/step - loss: 4.1173e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0302
# Epoch 83/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.1018e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0029 - val_mean_absolute_error: 0.0383
# Epoch 84/100
# 23/23 [==============================] - 1s 66ms/step - loss: 4.1905e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0022 - val_mean_absolute_error: 0.0311
# Epoch 85/100
# 23/23 [==============================] - 1s 47ms/step - loss: 4.1485e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0022 - val_mean_absolute_error: 0.0309
# Epoch 86/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.1787e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0023 - val_mean_absolute_error: 0.0320
# Epoch 87/100
# 23/23 [==============================] - 1s 47ms/step - loss: 3.9567e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0016 - val_mean_absolute_error: 0.0256
# Epoch 88/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.0772e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0020 - val_mean_absolute_error: 0.0298
# Epoch 89/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.0599e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0020 - val_mean_absolute_error: 0.0300
# Epoch 90/100
# 23/23 [==============================] - 1s 54ms/step - loss: 4.0683e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0019 - val_mean_absolute_error: 0.0287
# Epoch 91/100
# 23/23 [==============================] - 2s 83ms/step - loss: 4.1032e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0036 - val_mean_absolute_error: 0.0439
# Epoch 92/100
# 23/23 [==============================] - 2s 81ms/step - loss: 4.1573e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0022 - val_mean_absolute_error: 0.0313
# Epoch 93/100
# 23/23 [==============================] - 1s 54ms/step - loss: 4.0560e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0029 - val_mean_absolute_error: 0.0386
# Epoch 94/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.9541e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0016 - val_mean_absolute_error: 0.0262
# Epoch 95/100
# 23/23 [==============================] - 1s 50ms/step - loss: 3.9603e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0024 - val_mean_absolute_error: 0.0361
# Epoch 96/100
# 23/23 [==============================] - 1s 49ms/step - loss: 4.2368e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0018 - val_mean_absolute_error: 0.0274
# Epoch 97/100
# 23/23 [==============================] - 1s 65ms/step - loss: 3.9160e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0016 - val_mean_absolute_error: 0.0256
# Epoch 98/100
# 23/23 [==============================] - 1s 66ms/step - loss: 4.3441e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0019 - val_mean_absolute_error: 0.0286
# Epoch 99/100
# 23/23 [==============================] - 1s 51ms/step - loss: 4.0009e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0015 - val_mean_absolute_error: 0.0247
# Epoch 100/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.6480e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0015 - val_mean_absolute_error: 0.0254

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 3s 18ms/step
# array([[0.69726324, 0.69511694],
#        [0.6137333 , 0.62525064],
#        [0.61694825, 0.62235254],
#        [0.60866517, 0.6143963 ],
#        [0.6175596 , 0.62136966]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[553.5664 , 552.11145],
#        [515.27374, 520.126  ],
#        [516.74756, 518.7992 ],
#        [512.9503 , 515.15674],
#        [517.02783, 518.34924]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-202:].copy(),
pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=df.iloc[-202:].index)], axis=1)

# %%
df_merge[['Open','Close']] = MMS.inverse_transform(df_merge[['Open','Close']])
df_merge.head()
# Out:
#                   Open       Close  open_predicted  close_predicted
# Date
# 2021-04-21  508.000000  508.899994      553.566406       552.111450
# 2021-04-22  513.820007  508.779999      515.273743       520.125977
# 2021-04-23  509.010010  505.549988      516.747559       518.799194
# 2021-04-26  506.760010  510.299988      512.950317       515.156738
# 2021-04-27  512.619995  505.549988      517.027832       518.349243

# %%
df_merge[['Open','open_predicted']].plot(figsize=(10,6),color=['purple','orange'])
plt.xticks(rotation=0)
plt.xlabel('Year',size=20)
plt.ylabel('Price',size=20)
plt.title('Actual Open Price vs Predicted Open Price',size=20)
plt.show()

# %%
df_merge[['Close','close_predicted']].plot(figsize=(10,6),color=['darkgreen','red'])
plt.xticks(rotation=0)
plt.xlabel('Year',size=20)
plt.ylabel('Price',size=20)
plt.title('Actual close price vs Predicted close price',size=20)
plt.show()

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                   Open       Close  open_predicted  close_predicted
# 2021-06-09  494.500000  485.809998      500.395203       503.227051
# 2021-06-10  487.170013  487.269989      494.071350       497.748505
# 2021-06-11  490.000000  488.769989      495.094025       498.099884
# 2021-06-14  489.679993  499.890015      496.482422       499.190704
# 2021-06-15  501.230011  491.899994      506.846741       508.020386
# 2021-06-16  495.000000  492.410004      499.593872       502.648376

# %%
upcoming_prediction = pd.DataFrame(columns=['Open','Close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]
for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
upcoming_prediction[['Open','Close']] = MMS.inverse_transform(upcoming_prediction[['Open','Close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'Open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'Open'],label='Upcoming Open␣Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=0)
ax.set_xlabel('Year',size=20)
ax.set_ylabel('Price',size=20)
ax.set_title('Upcoming Open price prediction',size=20)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'Close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'Close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=0)
ax.set_xlabel('Year',size=20)
ax.set_ylabel('Price',size=20)
ax.set_title('Upcoming close price prediction',size=20)
ax.legend()
fig.show()
